# %%
from statistics import*

# %%
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
promedio=sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
mediana=median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
moda= mode(grupoa)
print(moda)
# Out:
# 70

# %%
#ejemplo dos
tiempo100mt=[15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempo100mt)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("el tiempo promedio de los corredores es de", mean(tiempo100mt)  )
# Out:
# el tiempo promedio de los corredores es de 17.322

# %%
mediana=median(tiempo100mt)
print("la media de los tiempos de los corredores es", mediana)
# Out:
# la media de los tiempos de los corredores es 17.2

# %%
moda=mode(tiempo100mt)
print("la moda de los tiempos es", moda)
# Out:
# la moda de los tiempos es 15.1

# %%
multimodas=multimode(tiempo100mt)
print("las modas de los tiempos es", multimodas)
# Out:
# las modas de los tiempos es [15.1, 17.2]

# %% [markdown]
# ## ejemplo 3 histogramas de dos grupos
# 1. en este ejemplo creamos una lista de 100 numeros reales que represetan la produccion diaria de 100 telares(mediads en metros)
# 2. generamos otra lista con la produccion de 100 telares para una segunda fabrica
# 3. con estas listas de valores se pretende determinar las medias de tendencia central es decir la medi, la moda y la mediana y la desviacion estandar
# 4. graficar un histograma para cada fabrica

# %%
import random

# %%
fabrica1=[]
for i in range(100):
  numero_aletorio=round(random.uniform(50,100),2)
  fabrica1.append(numero_aletorio)
print(fabrica1)
# Out:
# [61.25, 99.25, 85.32, 95.87, 81.96, 51.28, 75.65, 85.45, 90.81, 91.49, 86.36, 59.85, 55.01, 75.62, 66.84, 76.06, 88.94, 68.0, 59.03, 75.76, 66.13, 58.1, 92.25, 58.65, 76.29, 68.93, 54.07, 95.27, 76.61, 63.93, 95.9, 89.2, 92.24, 51.33, 53.84, 95.22, 76.82, 94.19, 61.8, 85.8, 84.91, 82.77, 80.07, 52.95, 72.32, 93.51, 97.39, 82.6, 56.4, 86.59, 73.46, 79.53, 67.36, 69.99, 74.39, 76.96, 69.51, 75.36, 99.58, 61.59, 87.9, 77.39, 87.55, 52.78, 72.05, 78.25, 66.98, 92.54, 79.34, 69.1, 72.43, 82.1, 96.12, 83.25, 90.79, 76.25, 96.03, 63.98, 89.3, 93.38, 51.56, 89.71, 55.15, 50.97, 72.39, 90.66, 78.14, 63.8, 74.76, 60.79, 75.9, 73.62, 71.25, 90.51, 50.23, 85.24, 93.9, 55.94, 62.37, 71.21]

# %%
fabrica2=[]
for i in range(100):
  numero_aletorio=round(random.uniform(50,100),2)
  fabrica2.append(numero_aletorio)
print(fabrica2)
# Out:
# [79.77, 98.55, 61.42, 56.75, 97.89, 73.97, 56.84, 65.61, 61.34, 84.86, 62.08, 84.02, 90.83, 57.94, 99.97, 59.63, 85.33, 79.18, 85.47, 97.52, 66.18, 54.23, 50.6, 67.7, 54.52, 94.14, 66.93, 62.99, 60.24, 72.6, 77.39, 50.75, 95.13, 90.37, 97.2, 97.28, 98.57, 66.09, 80.44, 53.6, 84.38, 60.36, 53.56, 76.9, 69.84, 67.72, 97.69, 52.77, 90.97, 52.15, 88.66, 94.53, 62.85, 61.75, 62.63, 89.0, 78.39, 53.44, 81.39, 80.59, 72.15, 81.9, 86.75, 80.66, 50.04, 61.01, 65.91, 77.19, 84.78, 77.16, 57.75, 69.22, 90.71, 94.02, 88.11, 79.36, 73.28, 83.05, 54.43, 88.47, 59.58, 63.04, 61.97, 81.94, 95.14, 89.99, 73.67, 85.65, 63.51, 62.13, 71.68, 52.97, 89.33, 59.35, 78.34, 64.35, 53.56, 55.91, 86.56, 58.85]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("histograma fabrica 1")
# Out:
# Text(0.5, 1.0, 'histograma fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("histograma fabrica 2")
# Out:
# Text(0.5, 1.0, 'histograma fabrica 2')

# %%
media =mean (fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)
print("valores de la fabrica 1")
print("la media es",media)
print("la mediana es",mediana)
print("la moda es",moda)
# Out:
# valores de la fabrica 1
# la media es 75.9922
# la mediana es 76.155
# la moda es 61.25

# %%
media =mean (fabrica2)
mediana=median(fabrica2)
moda=mode(fabrica2)
print("valores de la fabrica 2")
print("la media es",media)
print("la mediana es",mediana)
print("la moda es",moda)
# Out:
# valores de la fabrica 2
# la media es 73.7896
# la mediana es 73.475
# la moda es 53.56

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1, ncols=2)

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
media1 =mean (fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
plt.hist(fabrica1, bins=10, alpha=0.2,color="b", edgecolor="black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label="media")
plt.axvline(mediana1, color="r", linestyle="dashed", linewidth=2, label="mediana")
plt.axvline(moda1, color="y", linestyle="dashed", linewidth=2, label="moda")
plt.xlabel=("valor")
plt.ylabel=("frecuencia")
plt.title("producion de la fabrica 1")
plt.legend()
plt.show()

# %%
media2 =mean (fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
plt.hist(fabrica2, bins=10, alpha=0.2,color="b", edgecolor="black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label="media")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label="mediana")
plt.axvline(moda2, color="y", linestyle="dashed", linewidth=2, label="moda")
plt.xlabel=("valor")
plt.ylabel=("frecuencia")
plt.title("producion de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ##maximo, minimo y rango

# %%
maximo= max(fabrica1)
minimo=min(fabrica1)
rango= maximo-minimo
media=mean(fabrica1)
moda=mode(fabrica1)
mediana=median(fabrica1)
print("esrtadistica descriptiva de la fabrica 1\n","media=", media,"\n mediana",mediana,"\n moda", moda,"\n maximo", maximo,"\n rango", rango,"\n minimo",minimo)
# Out:
# esrtadistica descriptiva de la fabrica 1
#  media= 75.9922
#  mediana 76.155
#  moda 61.25
#  maximo 99.58
#  rango 49.35
#  minimo 50.23

# %%
maximo2= max(fabrica2)
minimo2=min(fabrica2)
rango2= maximo-minimo
media2=mean(fabrica2)
moda2=mode(fabrica2)
mediana2=median(fabrica2)
print("esrtadistica descriptiva de la fabrica 1\n","media=", media2,"\n mediana",mediana2,"\n moda", moda2,"\n maximo", maximo2,"\n rango", rango2,"\n minimo",minimo2)
# Out:
# esrtadistica descriptiva de la fabrica 1
#  media= 73.7896
#  mediana 73.475
#  moda 53.56
#  maximo 99.97
#  rango 49.35
#  minimo 50.04

# %% [markdown]
# #DISPERCION DE LOS DATOS

# %%
DESV1=stdev(fabrica1)
print("la desviacion estandar de la fabrica 1 es de \n", DESV1)
# Out:
# la desviacion estandar de la fabrica 1 es de
#  13.898174110146973

# %%
DESV2=stdev(fabrica2)
print("la desviacion estandar de la fabrica 2 es de \n", DESV2)
# Out:
# la desviacion estandar de la fabrica 2 es de
#  14.79694146119598

# %%
media1 =mean (fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
plt.hist(fabrica1, bins=10, alpha=0.2,color="b", edgecolor="black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label=f"media={media1:.2f}")
plt.axvline(mediana1, color="r", linestyle="dashed", linewidth=2, label=f"mediana={mediana1:.2f}")
plt.axvline(moda1, color="y", linestyle="dashed", linewidth=2, label=f"moda={moda1:.2f}")

plt.axvline(media1 - DESV1, color="black", linestyle="dashed", linewidth=2, label=f"desviacion estandar={DESV1:.2}")
plt.axvline(media1+DESV1, color="black", linestyle="dashed", linewidth=2)
plt.xlabel=("valor")
plt.ylabel=("frecuencia")
plt.title("producion de la fabrica 1")
plt.legend()
plt.show()

# %%
media2 =mean (fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
plt.hist(fabrica2, bins=10, alpha=0.2,color="b", edgecolor="black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label=f"media={media2:.2f}")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label=f"mediana={mediana2:.2f}")
plt.axvline(moda2, color="y", linestyle="dashed", linewidth=2, label=f"moda={moda2:.2f}")

plt.axvline(media2 - DESV2, color="black", linestyle="dashed", linewidth=2, label=f"desviacion estandar={DESV2:.2}")
plt.axvline(media2+DESV2, color="black", linestyle="dashed", linewidth=2)
plt.xlabel=("valor")
plt.ylabel=("frecuencia")
plt.title("producion de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# #tablas de frecuencia

# %%
edades=[]
for i in range(100):
  numero_al=random.randint(18,70)
  edades.append(numero_al)
print(edades)
# Out:
# [23, 70, 50, 43, 42, 61, 36, 51, 22, 70, 32, 34, 41, 28, 22, 29, 51, 67, 19, 54, 43, 45, 70, 22, 30, 51, 39, 26, 40, 23, 45, 36, 49, 62, 29, 22, 64, 24, 27, 48, 27, 46, 31, 50, 36, 42, 59, 54, 39, 62, 60, 64, 41, 22, 20, 34, 23, 33, 45, 59, 43, 51, 33, 55, 61, 54, 37, 40, 45, 22, 26, 53, 65, 35, 45, 43, 50, 46, 29, 62, 41, 63, 24, 68, 19, 40, 57, 49, 58, 44, 64, 22, 60, 57, 46, 58, 37, 67, 58, 64]

# %%
import pandas as pd

# %%
df_edades = pd.DataFrame(edades, columns=["edad"])
df_edades
# Out:
#     edad
# 0     23
# 1     70
# 2     50
# 3     43
# 4     42
# ..   ...
# 95    58
# 96    37
# 97    67
# 98    58
# 99    64
#
# [100 rows x 1 columns]

# %%
##calcular la tabla de distribucion de frecunecias

tablafre = df_edades["edad"].value_counts().reset_index()
tablafre.columns = ["edad", "frecuencia"]
tablafre = tablafre.sort_values(by="edad")
tablafre
# Out:
#     edad  frecuencia
# 27    19           2
# 38    20           1
# 0     22           7
# 5     23           3
# 22    24           2
# 24    26           2
# 21    27           2
# 39    28           1
# 10    29           3
# 42    30           1
# 40    31           1
# 37    32           1
# 17    33           2
# 29    34           2
# 34    35           1
# 12    36           3
# 19    37           2
# 30    39           2
# 7     40           3
# 11    41           3
# 25    42           2
# 2     43           4
# 43    44           1
# 1     45           5
# 9     46           3
# 41    48           1
# 23    49           2
# 14    50           3
# 4     51           4
# 31    53           1
# 8     54           3
# 36    55           1
# 20    57           2
# 13    58           3
# 18    59           2
# 16    60           2
# 26    61           2
# 6     62           3
# 33    63           1
# 3     64           4
# 35    65           1
# 28    67           2
# 32    68           1
# 15    70           3

# %%
tablafre["frecuencia relativa"]=tablafre["frecuencia"]/100

# %%
tablafre
# Out:
#     edad  frecuencia  frecuencia relativa
# 27    19           2                 0.02
# 38    20           1                 0.01
# 0     22           7                 0.07
# 5     23           3                 0.03
# 22    24           2                 0.02
# 24    26           2                 0.02
# 21    27           2                 0.02
# 39    28           1                 0.01
# 10    29           3                 0.03
# 42    30           1                 0.01
# 40    31           1                 0.01
# 37    32           1                 0.01
# 17    33           2                 0.02
# 29    34           2                 0.02
# 34    35           1                 0.01
# 12    36           3                 0.03
# 19    37           2                 0.02
# 30    39           2                 0.02
# 7     40           3                 0.03
# 11    41           3                 0.03
# 25    42           2                 0.02
# 2     43           4                 0.04
# 43    44           1                 0.01
# 1     45           5                 0.05
# 9     46           3                 0.03
# 41    48           1                 0.01
# 23    49           2                 0.02
# 14    50           3                 0.03
# 4     51           4                 0.04
# 31    53           1                 0.01
# 8     54           3                 0.03
# 36    55           1                 0.01
# 20    57           2                 0.02
# 13    58           3                 0.03
# 18    59           2                 0.02
# 16    60           2                 0.02
# 26    61           2                 0.02
# 6     62           3                 0.03
# 33    63           1                 0.01
# 3     64           4                 0.04
# 35    65           1                 0.01
# 28    67           2                 0.02
# 32    68           1                 0.01
# 15    70           3                 0.03

# %%
tablafre["frecuencia porcentual"] = (tablafre["frecuencia"] / tablafre["frecuencia"].sum()) * 100

tablafre
# Out:
#     edad  frecuencia  frecuencia relativa  frecuencia porcentual
# 27    19           2                 0.02                    2.0
# 38    20           1                 0.01                    1.0
# 0     22           7                 0.07                    7.0
# 5     23           3                 0.03                    3.0
# 22    24           2                 0.02                    2.0
# 24    26           2                 0.02                    2.0
# 21    27           2                 0.02                    2.0
# 39    28           1                 0.01                    1.0
# 10    29           3                 0.03                    3.0
# 42    30           1                 0.01                    1.0
# 40    31           1                 0.01                    1.0
# 37    32           1                 0.01                    1.0
# 17    33           2                 0.02                    2.0
# 29    34           2                 0.02                    2.0
# 34    35           1                 0.01                    1.0
# 12    36           3                 0.03                    3.0
# 19    37           2                 0.02                    2.0
# 30    39           2                 0.02                    2.0
# 7     40           3                 0.03                    3.0
# 11    41           3                 0.03                    3.0
# 25    42           2                 0.02                    2.0
# 2     43           4                 0.04                    4.0
# 43    44           1                 0.01                    1.0
# 1     45           5                 0.05                    5.0
# 9     46           3                 0.03                    3.0
# 41    48           1                 0.01                    1.0
# 23    49           2                 0.02                    2.0
# 14    50           3                 0.03                    3.0
# 4     51           4                 0.04                    4.0
# 31    53           1                 0.01                    1.0
# 8     54           3                 0.03                    3.0
# 36    55           1                 0.01                    1.0
# 20    57           2                 0.02                    2.0
# 13    58           3                 0.03                    3.0
# 18    59           2                 0.02                    2.0
# 16    60           2                 0.02                    2.0
# 26    61           2                 0.02                    2.0
# 6     62           3                 0.03                    3.0
# 33    63           1                 0.01                    1.0
# 3     64           4                 0.04                    4.0
# 35    65           1                 0.01                    1.0
# 28    67           2                 0.02                    2.0
# 32    68           1                 0.01                    1.0
# 15    70           3                 0.03                    3.0

# %%
#frecuencia acumulada
tablafre["frecuencia acumulada"] = tablafre["frecuencia"].cumsum()
tablafre
# Out:
#     edad  frecuencia  frecuencia relativa  frecuencia porcentual  \
# 27    19           2                 0.02                    2.0
# 38    20           1                 0.01                    1.0
# 0     22           7                 0.07                    7.0
# 5     23           3                 0.03                    3.0
# 22    24           2                 0.02                    2.0
# 24    26           2                 0.02                    2.0
# 21    27           2                 0.02                    2.0
# 39    28           1                 0.01                    1.0
# 10    29           3                 0.03                    3.0
# 42    30           1                 0.01                    1.0
# 40    31           1                 0.01                    1.0
# 37    32           1                 0.01                    1.0
# 17    33           2                 0.02                    2.0
# 29    34           2                 0.02                    2.0
# 34    35           1                 0.01                    1.0
# 12    36           3                 0.03                    3.0
# 19    37           2                 0.02                    2.0
# 30    39           2                 0.02                    2.0
# 7     40           3                 0.03                    3.0
# 11    41           3                 0.03                    3.0
# 25    42           2                 0.02                    2.0
# 2     43           4                 0.04                    4.0
# 43    44           1                 0.01                    1.0
# 1     45           5                 0.05                    5.0
# 9     46           3                 0.03                    3.0
# 41    48           1                 0.01                    1.0
# 23    49           2                 0.02                    2.0
# 14    50           3                 0.03                    3.0
# 4     51           4                 0.04                    4.0
# 31    53           1                 0.01                    1.0
# 8     54           3                 0.03                    3.0
# 36    55           1                 0.01                    1.0
# 20    57           2                 0.02                    2.0
# 13    58           3                 0.03                    3.0
# 18    59           2                 0.02                    2.0
# 16    60           2                 0.02                    2.0
# 26    61           2                 0.02                    2.0
# 6     62           3                 0.03                    3.0
# 33    63           1                 0.01                    1.0
# 3     64           4                 0.04                    4.0
# 35    65           1                 0.01                    1.0
# 28    67           2                 0.02                    2.0
# 32    68           1                 0.01                    1.0
# 15    70           3                 0.03                    3.0
#
#     frecuencia acumulada
# 27                     2
# 38                     3
# 0                     10
# 5                     13
# 22                    15
# 24                    17
# 21                    19
# 39                    20
# 10                    23
# 42                    24
# 40                    25
# 37                    26
# 17                    28
# 29                    30
# 34                    31
# 12                    34
# 19                    36
# 30                    38
# 7                     41
# 11                    44
# 25                    46
# 2                     50
# 43                    51
# 1                     56
# 9                     59
# 41                    60
# 23                    62
# 14                    65
# 4                     69
# 31                    70
# 8                     73
# 36                    74
# 20                    76
# 13                    79
# 18                    81
# 16                    83
# 26                    85
# 6                     88
# 33                    89
# 3                     93
# 35                    94
# 28                    96
# 32                    97
# 15                   100

# %% [markdown]
# #regla de sturges

# %%
import math

# %%
df_edades_s=pd.DataFrame({"edades":edades})
df_edades_s
# Out:
#     edades
# 0       23
# 1       70
# 2       50
# 3       43
# 4       42
# ..     ...
# 95      58
# 96      37
# 97      67
# 98      58
# 99      64
#
# [100 rows x 1 columns]

# %%
n=len(edades)
k=int(1 + math.log2(n))
print("valor de b=",n,"k o numero de intervalos",k)
# Out:
# valor de b= 100 k o numero de intervalos 7

# %%
plt.hist(edades, alpha=0.5, rwidth=0.95)
plt.title("histograma de edades basado en valores de matplotlib")
# Out:
# Text(0.5, 1.0, 'histograma de edades basado en valores de matplotlib')

# %%
tablades = pd.cut(df_edades_s["edades"], bins = k).value_counts().reset_index()
tablades
# Out:
#               index  edades
# 0  (40.857, 48.143]      19
# 1  (18.949, 26.286]      17
# 2  (48.143, 55.429]      14
# 3  (55.429, 62.714]      14
# 4  (33.571, 40.857]      13
# 5    (62.714, 70.0]      12
# 6  (26.286, 33.571]      11

# %%
tablades.columns=["clase", "frecuencias"]
tablades
# Out:
#               clase  frecuencias
# 0  (40.857, 48.143]           19
# 1  (18.949, 26.286]           17
# 2  (48.143, 55.429]           14
# 3  (55.429, 62.714]           14
# 4  (33.571, 40.857]           13
# 5    (62.714, 70.0]           12
# 6  (26.286, 33.571]           11

# %%
tablades=tablades.sort_values(by="clase")
tablades
# Out:
#               clase  frecuencias
# 1  (18.949, 26.286]           17
# 6  (26.286, 33.571]           11
# 4  (33.571, 40.857]           13
# 0  (40.857, 48.143]           19
# 2  (48.143, 55.429]           14
# 3  (55.429, 62.714]           14
# 5    (62.714, 70.0]           12

# %%
tablades["frec relativa"]= tablades["frecuencias"]/n
tablades["frec porcentual"]= tablades["frecuencias"]/n*100
tablades["frec acunulada"]= tablades["frecuencias"].cumsum()

# %%
tablades
# Out:
#               clase  frecuencias  frec relativa  frec porcentual  \
# 1  (18.949, 26.286]           17           0.17             17.0
# 6  (26.286, 33.571]           11           0.11             11.0
# 4  (33.571, 40.857]           13           0.13             13.0
# 0  (40.857, 48.143]           19           0.19             19.0
# 2  (48.143, 55.429]           14           0.14             14.0
# 3  (55.429, 62.714]           14           0.14             14.0
# 5    (62.714, 70.0]           12           0.12             12.0
#
#    frec acunulada
# 1              17
# 6              28
# 4              41
# 0              60
# 2              74
# 3              88
# 5             100

# %%
plt.hist(df_edades_s["edades"],bins=k, alpha=0.5, rwidth=.95)
plt.title("histograma basado eb la regla de sturges")
# Out:
# Text(0.5, 1.0, 'histograma basado eb la regla de sturges')
