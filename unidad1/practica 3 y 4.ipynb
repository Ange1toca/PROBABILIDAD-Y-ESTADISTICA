# %%
from statistics import*

# %%
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
promedio=sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
mediana=median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
moda= mode(grupoa)
print(moda)
# Out:
# 70

# %%
#ejemplo dos
tiempo100mt=[15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempo100mt)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("el tiempo promedio de los corredores es de", mean(tiempo100mt)  )
# Out:
# el tiempo promedio de los corredores es de 17.322

# %%
mediana=median(tiempo100mt)
print("la media de los tiempos de los corredores es", mediana)
# Out:
# la media de los tiempos de los corredores es 17.2

# %%
moda=mode(tiempo100mt)
print("la moda de los tiempos es", moda)
# Out:
# la moda de los tiempos es 15.1

# %%
multimodas=multimode(tiempo100mt)
print("las modas de los tiempos es", multimodas)
# Out:
# las modas de los tiempos es [15.1, 17.2]

# %% [markdown]
# ## ejemplo 3 histogramas de dos grupos
# 1. en este ejemplo creamos una lista de 100 numeros reales que represetan la produccion diaria de 100 telares(mediads en metros)
# 2. generamos otra lista con la produccion de 100 telares para una segunda fabrica
# 3. con estas listas de valores se pretende determinar las medias de tendencia central es decir la medi, la moda y la mediana y la desviacion estandar
# 4. graficar un histograma para cada fabrica

# %%
import random

# %%
fabrica1=[]
for i in range(100):
  numero_aletorio=round(random.uniform(50,100),2)
  fabrica1.append(numero_aletorio)
print(fabrica1)
# Out:
# [87.9, 79.85, 65.26, 90.68, 75.53, 66.76, 55.46, 71.19, 63.12, 99.32, 52.27, 72.78, 72.93, 52.91, 76.27, 66.86, 64.75, 57.09, 51.34, 61.83, 65.83, 71.64, 54.74, 98.52, 55.83, 87.64, 63.32, 56.91, 61.93, 70.29, 85.26, 56.87, 57.2, 79.7, 54.14, 93.95, 74.23, 80.82, 80.61, 58.83, 80.09, 86.76, 60.22, 50.97, 60.35, 78.46, 78.6, 54.16, 82.17, 97.99, 85.61, 88.17, 50.04, 64.39, 88.01, 82.7, 71.49, 65.86, 59.27, 84.71, 82.13, 61.16, 68.4, 96.47, 59.39, 84.45, 55.08, 53.09, 80.68, 77.12, 80.23, 60.45, 50.09, 88.31, 79.58, 61.34, 66.04, 70.7, 75.69, 94.39, 94.24, 52.26, 98.49, 99.4, 82.05, 92.22, 69.82, 66.41, 53.71, 87.0, 96.18, 53.98, 93.03, 87.91, 59.54, 65.38, 71.24, 72.82, 89.23, 85.56]

# %%
fabrica2=[]
for i in range(100):
  numero_aletorio=round(random.uniform(50,100),2)
  fabrica2.append(numero_aletorio)
print(fabrica2)
# Out:
# [56.41, 50.39, 65.07, 95.67, 96.91, 87.1, 87.09, 61.99, 70.9, 55.02, 58.6, 75.15, 55.25, 58.56, 52.17, 87.06, 85.9, 88.63, 71.76, 66.6, 59.96, 74.55, 89.63, 82.25, 53.89, 69.14, 50.04, 99.04, 51.65, 58.82, 82.8, 68.43, 97.56, 58.11, 51.3, 52.98, 70.01, 86.6, 62.21, 52.02, 51.34, 60.53, 96.68, 76.52, 88.01, 63.86, 63.22, 60.1, 98.9, 66.63, 96.97, 64.6, 66.09, 73.95, 61.92, 68.04, 57.72, 69.63, 74.64, 87.88, 62.0, 85.82, 74.87, 87.25, 56.71, 83.72, 78.13, 92.78, 94.1, 84.4, 87.93, 60.22, 87.49, 86.73, 57.69, 94.59, 95.6, 96.4, 67.88, 77.59, 91.95, 91.53, 60.89, 94.21, 84.93, 50.18, 62.68, 86.52, 94.38, 82.77, 61.1, 77.23, 61.75, 82.85, 84.39, 95.66, 60.01, 53.63, 79.07, 53.81]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("histograma fabrica 1")
# Out:
# Text(0.5, 1.0, 'histograma fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("histograma fabrica 2")
# Out:
# Text(0.5, 1.0, 'histograma fabrica 2')

# %%
media =mean (fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)
print("valores de la fabrica 1")
print("la media es",media)
print("la mediana es",mediana)
print("la moda es",moda)
# Out:
# valores de la fabrica 1
# la media es 72.7764
# la mediana es 71.565
# la moda es 87.9

# %%
media =mean (fabrica2)
mediana=median(fabrica2)
moda=mode(fabrica2)
print("valores de la fabrica 2")
print("la media es",media)
print("la mediana es",mediana)
print("la moda es",moda)
# Out:
# valores de la fabrica 2
# la media es 73.6589
# la mediana es 72.855
# la moda es 56.41

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1, ncols=2)

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
media1 =mean (fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
plt.hist(fabrica1, bins=10, alpha=0.2,color="b", edgecolor="black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label="media")
plt.axvline(mediana1, color="r", linestyle="dashed", linewidth=2, label="mediana")
plt.axvline(moda1, color="y", linestyle="dashed", linewidth=2, label="moda")
plt.xlabel=("valor")
plt.ylabel=("frecuencia")
plt.title("producion de la fabrica 1")
plt.legend()
plt.show()

# %%
media2 =mean (fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
plt.hist(fabrica2, bins=10, alpha=0.2,color="b", edgecolor="black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label="media")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label="mediana")
plt.axvline(moda2, color="y", linestyle="dashed", linewidth=2, label="moda")
plt.xlabel=("valor")
plt.ylabel=("frecuencia")
plt.title("producion de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ##maximo, minimo y rango

# %%
maximo= max(fabrica1)
minimo=min(fabrica1)
rango= maximo-minimo
media=mean(fabrica1)
moda=mode(fabrica1)
mediana=median(fabrica1)
print("esrtadistica descriptiva de la fabrica 1\n","media=", media,"\n mediana",mediana,"\n moda", moda,"\n maximo", maximo,"\n rango", rango,"\n minimo",minimo2)
# Out:
# esrtadistica descriptiva de la fabrica 1
#  media= 72.7764
#  mediana 71.565
#  moda 87.9
#  maximo 99.4
#  rango 49.36000000000001
#  minimo 50.42

# %%
maximo2= max(fabrica2)
minimo2=min(fabrica2)
rango2= maximo-minimo
media2=mean(fabrica2)
moda2=mode(fabrica2)
mediana2=median(fabrica2)
print("esrtadistica descriptiva de la fabrica 1\n","media=", media2,"\n mediana",mediana2,"\n moda", moda2,"\n maximo", maximo2,"\n rango", rango2,"\n minimo",minimo2)
# Out:
# esrtadistica descriptiva de la fabrica 1
#  media= 73.6589
#  mediana 72.855
#  moda 56.41
#  maximo 99.04
#  rango 49.36000000000001
#  minimo 50.04

# %% [markdown]
# #DISPERCION DE LOS DATOS

# %%
DESV1=stdev(fabrica1)
print("la desviacion estandar de la fabrica 1 es de \n", DESV1)
# Out:
# la desviacion estandar de la fabrica 1 es de
#  14.33771113694458

# %%
DESV2=stdev(fabrica2)
print("la desviacion estandar de la fabrica 2 es de \n", DESV2)
# Out:
# la desviacion estandar de la fabrica 2 es de
#  15.216971711569522

# %%
media1 =mean (fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
plt.hist(fabrica1, bins=10, alpha=0.2,color="b", edgecolor="black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label=f"media={media1:.2f}")
plt.axvline(mediana1, color="r", linestyle="dashed", linewidth=2, label=f"mediana={mediana1:.2f}")
plt.axvline(moda1, color="y", linestyle="dashed", linewidth=2, label=f"moda={moda1:.2f}")

plt.axvline(media1 - DESV1, color="black", linestyle="dashed", linewidth=2, label=f"desviacion estandar={DESV1:.2}")
plt.axvline(media1+DESV1, color="black", linestyle="dashed", linewidth=2)
plt.xlabel=("valor")
plt.ylabel=("frecuencia")
plt.title("producion de la fabrica 1")
plt.legend()
plt.show()

# %%
media2 =mean (fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
plt.hist(fabrica2, bins=10, alpha=0.2,color="b", edgecolor="black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label=f"media={media2:.2f}")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label=f"mediana={mediana2:.2f}")
plt.axvline(moda2, color="y", linestyle="dashed", linewidth=2, label=f"moda={moda2:.2f}")

plt.axvline(media2 - DESV2, color="black", linestyle="dashed", linewidth=2, label=f"desviacion estandar={DESV2:.2}")
plt.axvline(media2+DESV2, color="black", linestyle="dashed", linewidth=2)
plt.xlabel=("valor")
plt.ylabel=("frecuencia")
plt.title("producion de la fabrica 2")
plt.legend()
plt.show()
