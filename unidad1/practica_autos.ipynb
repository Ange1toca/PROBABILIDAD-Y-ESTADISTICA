# %% [markdown]
# EJERCICIO 6 DE PROBABILIDAD Y ESTADISTICA

# %%
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from statistics import*
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files
data = pd.read_csv('/content/drive/MyDrive/autos2.csv')
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %% [markdown]
# # Estadisticas descriptivas básicas y medidas de tendencia centralva

# %%
data = pd.read_csv('/content/drive/MyDrive/autos2.csv')
data
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
print ("El valor minimo de los precios: \n" , data.price.min())
print ("El valor maximo de los precios: \n", data.price.max())
moda = multimode(data.price)
print ("La moda de los precios: \n" , moda)
print ("La media de los precios: \n" , data.price.mean())
print ("La mediana de los precios: \n" , data.price.median())
d = (data.price.std())
print ("La desviacion estandar de los precios es: \n", d)
data.describe()
# Out:
# El valor minimo de los precios:
#  5118.0
# El valor maximo de los precios:
#  45400.0
# La moda de los precios:
#  [16500.0, 5572.0, 7957.0, 6229.0, 6692.0, 7609.0, 8921.0, 7295.0, 8845.0, 8495.0, 9279.0, 13499.0, 18150.0, 7775.0, 7898.0]
# La media de los precios:
#  13207.129353233831
# La mediana de los precios:
#  10295.0
# La desviacion estandar de los precios es:
#  7947.066341939274
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          31.681008    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.100000   66.900000
# ...

# %% [markdown]
# # Realizar un Histograma de precios de los automoviles

# %%
n = len(data)
k = int (1+ math.log2(n))

print ("Valor de n=", n, "\nK o numero de intervalos o clases=", k)
plt.hist(data['price'], bins=8)
plt.xlabel('valores')
plt.ylabel('precio de los automoviles')
plt.title('histograma de precios de autos')
# Out:
# Valor de n= 205
# K o numero de intervalos o clases= 8
# Text(0.5, 1.0, 'histograma de precios de autos')

# %% [markdown]
# en el histograma podemos observar como el precio de los autos mas vendidos va desde los 5000 a 10000 dolares

# %% [markdown]
# # Realizar un diagrama de caja y bigotes que muestre la arelacion estadistica entre la columna del precio del automovil (price) y tipo de vehiculo (body style)

# %%
sns.boxplot(x = "body-style", y = "price", data=data)
plt.title("Relación Estadistica del precio del automóvil y el tipo de vehículo")
plt.xlabel("Estilo del Cuerpo del Automóvil")
plt.ylabel("Precio del Automóvil")
# Out:
# Text(0, 0.5, 'Precio del Automóvil')

# %% [markdown]
# con este diagrama de caja y bigote podemos ver la relacion que tiene el precio con los tipos de autos mas vndidos podemos ver como los autos mas baratos vendidos son de tipo hatchback, sedan y wagon y como los autos mas caros vendidos son de tipo hardtop y convertible

# %% [markdown]
# # Realizar un diagrama de caja y bigotes que muestre la arelacion estadistica entre la columna del precio del automovil (price) y tipo traccion ruedas (drive wheels)

# %%
sns.boxplot(x = "drive-wheels", y = "price", data=data)
plt.title("Relación Estadistica del precio del automóvil y el tipo de tracción de ruedas del vehículo.")
plt.xlabel("Tipo de Tracción")
plt.ylabel("Precio del Automóvil")
# Out:
# Text(0, 0.5, 'Precio del Automóvil')

# %% [markdown]
# con este diagrama podemos observar como los autos mayormente tienen una tracion trasera y como sus precios son desde los 13000 dolares hasta los 25000 dolares y lo autos co tracion delantera y 4x4 van desde los 5000 dolares hasta los 15000 dolares

# %% [markdown]
# #  Realizar un diagrama de caja y bigotes que muestre la arelacion estadistica entre la columna del precio del automovil (price) y la ubicacion del motor (engine-location)

# %%
sns.boxplot(x = "engine-location", y = "price", data=data)
plt.title("Relación Estadistica del precio del automóvil y la ubicación del motor.")
plt.xlabel("Ubicación del motor")
plt.ylabel("Precio del Automóvil")
# Out:
# Text(0, 0.5, 'Precio del Automóvil')

# %% [markdown]
# con este diagrama podemos observar como los autos mas caros tienen el motor en la parte trasera mientras que los autos mas baratos cuentan con el motor en la parte de adelante

# %% [markdown]
# # Conclusion
# la probabilidad y estadistica nos ayudan mucho en el analizar y comprender los datos de algunas cosas en esta practica nos ayudo a ver como los precios de lo carros van siendo modificados segun el tipo de carro que vemos y tambien nos ayudo para ver como el precio del carro aumenta o disminuye segun sus caractersiticas y el precio donde la gente mas compra sus autos que son de los 5000 dolares a los 10000 dolares
# muy interesante esta practica
