# %%
from statistics import*

# %%
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
promedio=sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
mediana=median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
moda= mode(grupoa)
print(moda)
# Out:
# 70

# %%
#ejemplo dos
tiempo100mt=[15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempo100mt)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("el tiempo promedio de los corredores es de", mean(tiempo100mt)  )
# Out:
# el tiempo promedio de los corredores es de 17.322

# %%
mediana=median(tiempo100mt)
print("la media de los tiempos de los corredores es", mediana)
# Out:
# la media de los tiempos de los corredores es 17.2

# %%
moda=mode(tiempo100mt)
print("la moda de los tiempos es", moda)

# %%
multimodas=multimode(tiempo100mt)
print("las modas de los tiempos es", multimodas)

# %% [markdown]
# ## ejemplo 3 histogramas de dos grupos
# 1. en este ejemplo creamos una lista de 100 numeros reales que represetan la produccion diaria de 100 telares(mediads en metros)
# 2. generamos otra lista con la produccion de 100 telares para una segunda fabrica
# 3. con estas listas de valores se pretende determinar las medias de tendencia central es decir la medi, la moda y la mediana y la desviacion estandar
# 4. graficar un histograma para cada fabrica

# %%
import random

# %%
fabrica1=[]
for i in range(100):
  numero_aletorio=round(random.uniform(50,100),2)
  fabrica1.append(numero_aletorio)
print(fabrica1)
# Out:
# [62.28, 55.15, 93.84, 96.92, 56.66, 64.98, 75.34, 77.6, 90.05, 53.45, 93.96, 59.98, 90.24, 79.47, 71.56, 90.29, 80.21, 91.71, 73.76, 68.18, 50.8, 77.73, 59.54, 56.98, 81.27, 60.5, 55.16, 92.14, 88.25, 96.22, 67.54, 64.72, 85.82, 87.06, 65.36, 65.25, 52.14, 63.01, 98.33, 88.42, 75.61, 57.26, 71.85, 52.55, 95.09, 65.7, 59.76, 88.93, 63.13, 89.7, 89.97, 77.34, 93.31, 52.37, 98.22, 56.41, 79.1, 99.83, 95.73, 67.33, 66.58, 71.98, 70.58, 55.14, 64.28, 98.24, 55.01, 94.0, 78.56, 93.78, 92.44, 64.11, 85.7, 89.92, 85.16, 86.07, 96.02, 69.88, 67.56, 50.52, 98.26, 89.88, 74.26, 82.99, 62.34, 61.64, 75.8, 60.28, 89.31, 50.23, 60.71, 63.18, 62.48, 87.98, 78.79, 99.04, 66.96, 75.37, 52.31, 62.17]

# %%
fabrica2=[]
for i in range(100):
  numero_aletorio=round(random.uniform(50,100),2)
  fabrica2.append(numero_aletorio)
print(fabrica2)
# Out:
# [94.22, 74.03, 57.51, 88.94, 85.9, 69.61, 54.23, 85.94, 61.76, 68.92, 63.24, 82.57, 54.71, 63.23, 63.3, 57.31, 84.22, 90.47, 95.41, 68.4, 78.65, 62.9, 82.69, 56.1, 74.47, 96.12, 52.45, 63.44, 57.76, 72.53, 79.43, 64.72, 67.9, 75.09, 89.75, 94.05, 63.81, 93.86, 83.82, 80.99, 60.8, 51.55, 74.54, 55.71, 84.26, 82.47, 89.42, 60.72, 76.41, 53.48, 76.8, 74.92, 68.69, 77.46, 56.88, 97.59, 77.86, 90.23, 85.87, 99.47, 65.99, 97.94, 79.19, 84.04, 55.56, 61.55, 99.88, 93.48, 69.52, 75.24, 61.85, 63.55, 97.15, 64.79, 74.53, 51.78, 77.43, 68.19, 82.24, 86.43, 73.39, 55.38, 80.93, 88.39, 76.93, 67.16, 78.77, 64.76, 84.11, 91.12, 51.54, 65.1, 86.81, 94.81, 96.62, 55.72, 96.0, 95.78, 91.42, 79.62]

# %%
import matplotlib.pyplot as plt
# Out:
# histograma fabrica 2

# %%
plt.hist(fabrica1)
plt.title("histograma fabrica 1")
# Out:
# Text(0.5, 1.0, 'histograma fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("histograma fabrica 2")
# Out:
# Text(0.5, 1.0, 'histograma fabrica 2')

# %%
media =mean (fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)
print("valores de la fabrica 1")
print("la media es",media)
print("la mediana es",mediana)
print("la moda es",moda)
# Out:
# valores de la fabrica 1
# la media es 75.0057
# la mediana es 74.80000000000001
# la moda es 62.28

# %%
media =mean (fabrica2)
mediana=median(fabrica2)
moda=mode(fabrica2)
print("valores de la fabrica 2")
print("la media es",media)
print("la mediana es",mediana)
print("la moda es",moda)
# Out:
# valores de la fabrica 2
# la media es 75.3427
# la mediana es 75.82499999999999
# la moda es 94.22

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1, ncols=2)
