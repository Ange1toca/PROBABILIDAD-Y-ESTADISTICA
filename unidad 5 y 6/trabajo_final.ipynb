# %% [markdown]
# # **trabajo final de probabilidad y estadistica regresion final y correlacion**
# ##Jose angel toca zamora
# ###Objetivo de la Práctica
# El objetivo de esta práctica es que los estudiantes apliquen los conceptos de regresión lineal simple y correlación a un conjunto de datos real. Los estudiantes deberán utilizar Python para analizar los datos, calcular la correlación entre dos variables, ajustar un modelo de regresión lineal, y visualizar los resultados obtenidos.

# %% [markdown]
# # Carga y Exploración de Datos:
# • Cargar el conjunto de datos utilizando Python (pandas).
#
# • Realizar una exploración inicial de los datos (descripción estadística y visualización).
#
# • Generar un histograma de calificaciones

# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression # Modelo de regresión Lineal
import numpy as np
from scipy.stats import pearsonr



# Montar Google Drive
drive.mount('/content/drive')

# Cargar los archivos CSV
data1 = pd.read_csv('/content/drive/MyDrive/grupo1.csv')
data2 = pd.read_csv('/content/drive/MyDrive/grupo2.csv')
data3 = pd.read_csv('/content/drive/MyDrive/grupo3.csv')

# Mostrar todos los datos de cada DataFrame
print("Grupo 1:")
print(data1.to_string())
print("")
print("Grupo 1 descripcion")
print(data1.describe())
print("-----------------------------------")
print("\nGrupo 2:")
print(data2.to_string())
print("")
print("Grupo 2 descripcion")
print(data2.describe())
print("-----------------------------------")
print("\nGrupo 3:")
print(data3.to_string())
print("")
print("Grupo 3 descripcion")
print(data3.describe())
print("-----------------------------------")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Grupo 1:
#     HorasEstudio  Calificacion
# 0          20.00         75.94
# 1          15.60         87.48
# 2          17.91         79.40
# 3          20.00         73.37
# 4          20.00         83.75
# 5          10.09         87.85
# 6          17.80         84.60
# 7          13.39         86.72
# 8          13.59         78.29
# 9          15.64         80.74
# 10         14.58         77.95
# 11         19.82         80.76
# 12         17.04         76.68
# 13         14.49         68.46
# 14         15.78         85.60
# 15         15.33         80.38
# 16         19.98         69.33
# 17         13.18         88.17
# 18         15.25         75.83
# 19         10.58         84.47
# 20          3.79         90.56
# 21         16.61         85.16
# 22         17.46         94.25
# 23         11.03         72.89
# 24         20.00         87.62
# ...

# %%
##histograma del grupo 1
plt.hist(data1['Calificacion'], bins=7, alpha=0.5)
plt.title("histograma del primer grupo")
plt.xlabel("Calificaciones finales")
plt.ylabel("Frecuencia")
plt.show()

# %%
#histograma del grupo 2
plt.hist(data2['Calificacion'], bins=7, alpha=0.5)
plt.title("histograma del segundo grupo")
plt.xlabel("Calificaciones finales")
plt.ylabel("Frecuencia")
plt.show()

# %%
#histograma del grupo 3
plt.hist(data3['Calificacion'], bins=7, alpha=0.5)
plt.title("histograma del tercer grupo")
plt.xlabel("Calificaciones finales")
plt.ylabel("Frecuencia")
plt.show()

# %%
#grupo1
horasEstudio = data1[['HorasEstudio']]
calificacion = data1[['Calificacion']]
modelo = LinearRegression()
modelo.fit(horasEstudio, calificacion)
print("Coeficiente de la pendiente:\n", modelo.coef_[0])
print("Intercepcion de la recta :\n", modelo.intercept_)
horasEstudio = data1['HorasEstudio'].values
calificacion = data1['Calificacion'].values
coeficiente_correlacion, grupo1_valor = pearsonr (horasEstudio, calificacion)
print ("Coeficiente de correlacion de Pearson:\n ", coeficiente_correlacion)
print ("Valor grupo 1: \n", grupo1_valor)
sns.scatterplot(x = horasEstudio , y = calificacion)
plt.title( "diagrama de dispersion entre las horas de estudio y las calificaciones ")
plt.xlabel( "horas de estudio")
plt.ylabel( "Calificaciones Final")
plt.grid(True)
plt.show()
sns.set(style="whitegrid")
sns.regplot(x="HorasEstudio", y="Calificacion", data=data1, scatter=True, color="blue")
plt.title("diagrama de dispersión de las horas de Estudio y de la  calificación Final")
plt.xlabel("Horas de estudio")
plt.ylabel("Calificaciones finales")
plt.grid(True)
plt.show()
# Out:
# Coeficiente de la pendiente:
#  [-0.10608151]
# Intercepcion de la recta :
#  [85.31068185]
# Coeficiente de correlacion de Pearson:
#   -0.057133344466469324
# Valor grupo 1:
#  0.6935088469237536

# %%
#grupo2
horasEstudio = data2[['HorasEstudio']]
calificacion = data2[['Calificacion']]
modelo = LinearRegression()
modelo.fit(horasEstudio, calificacion)
print("Coeficiente de la pendiente:\n", modelo.coef_[0])
print("Intercepcion de la recta :\n", modelo.intercept_)
horasEstudio = data2['HorasEstudio'].values
calificacion = data2['Calificacion'].values
coeficiente_correlacion, grupo2_valor = pearsonr (horasEstudio, calificacion)
print ("Coeficiente de correlacion de Pearson:\n ", coeficiente_correlacion)
print ("Valor grupo 2: \n", grupo2_valor)
sns.scatterplot(x = horasEstudio , y = calificacion)
plt.title( "diagrama de dispersion entre las horas de estudio y las calificaciones ")
plt.xlabel( "horas de estudio")
plt.ylabel( "Calificaciones Final")
plt.grid(True)
plt.show()
sns.set(style="whitegrid")
sns.regplot(x="HorasEstudio", y="Calificacion", data=data2, scatter=True, color="blue")
plt.title("diagrama de dispersión de las horas de Estudio y de la  calificación Final")
plt.xlabel("Horas de estudio")
plt.ylabel("Calificaciones finales")
plt.grid(True)
plt.show()
# Out:
# Coeficiente de la pendiente:
#  [4.22271865]
# Intercepcion de la recta :
#  [15.30754188]
# Coeficiente de correlacion de Pearson:
#   0.861989042650508
# Valor grupo 2:
#  9.077714233687994e-16

# %%
#grupo3
horasEstudio = data3[['HorasEstudio']]
calificacion = data3[['Calificacion']]
modelo = LinearRegression()
modelo.fit(horasEstudio, calificacion)
print("Coeficiente de la pendiente:\n", modelo.coef_[0])
print("Intercepcion de la recta :\n", modelo.intercept_)
horasEstudio = data3['HorasEstudio'].values
calificacion = data3['Calificacion'].values
coeficiente_correlacion, grupo3_valor = pearsonr (horasEstudio, calificacion)
print ("Coeficiente de correlacion de Pearson:\n ", coeficiente_correlacion)
print ("Valor grupo 3: \n", grupo3_valor)
sns.scatterplot(x = horasEstudio , y = calificacion)
plt.title( "diagrama de dispersion entre las horas de estudio y las calificaciones ")
plt.xlabel( "horas de estudio")
plt.ylabel( "Calificaciones Final")
plt.grid(True)
plt.show()
sns.set(style="whitegrid")
sns.regplot(x="HorasEstudio", y="Calificacion", data=data3, scatter=True, color="blue")
plt.title("diagrama de dispersión de las horas de Estudio y de la  calificación Final")
plt.xlabel("Horas de estudio")
plt.ylabel("Calificaciones finales")
plt.grid(True)
plt.show()
# Out:
# Coeficiente de la pendiente:
#  [5.28567095]
# Intercepcion de la recta :
#  [0.10805052]
# Coeficiente de correlacion de Pearson:
#   0.9422151342073145
# Valor grupo 3:
#  1.934152423102503e-24

# %% [markdown]
# # **INTERPRETACION DE LOS RESULTADOS OBTENIDOS DE LA PRACTICA**
#
# ###1. ¿Explicar cuál es la interpretación del coeficiente de regresión en términos de la relación entre el tiempo de estudio y las calificaciones finales?
# pues se logra observar como al tener mas horas de estudio se tiene una calificacion mas alta esto se puede obeservar de una manera mas clara en el grupo 3 etso hace que sea una relacion positiva entre el aumento de horas estudiadas y la calificacion final
# ###2.¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y dirección de la relación entre las variables?
# los coeficientes de correlación indican que, en general, más horas de estudio están asociadas con calificaciones más altas en los grupos 2 y 3, mientras que en el grupo 1, esta asociación es débil. Estos resultados resaltan la importancia de considerar el contexto específico de cada grupo al analizar la relación entre el tiempo de estudio y el rendimiento académico.
# ###3.¿El modelo de regresión lineal es estadísticamente significativo?
#
# Dado que todos los valores del grupo(g) son considerablemente menores que el nivel de significancia de 0.05, podemos concluir que el modelo de regresión lineal es estadísticamente significativo en todos los grupos
#
# ###4.¿Qué tan confiable es el modelo de regresión para predecir las calificaciones finales de los estudiantes basado en el tiempo de estudio?
# El modelo de regresión lineal es altamente confiable para predecir las calificaciones finales de los estudiantes basado en el tiempo de estudio en todos los grupos.

# %% [markdown]
# # **conclusiones**
# con esta practica podemos conlucir que el tiempo de estudio se relaciona con las calificaciones finales en tres grupos diferentes. Descubrimos que, en general, más tiempo de estudio está asociado con mejores calificaciones. Sin embargo, encontramos diferencias entre los grupos, lo que sugiere que otros factores pueden influir. Además, nuestros modelos de regresión fueron altamente significativos, lo que respalda la importancia del tiempo de estudio en el rendimiento académico, es decir que emtre mas horas de estudio tengas mas alta sera tu calificacion final.
